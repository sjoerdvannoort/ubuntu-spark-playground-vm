# %%
# %%sparksql
# SHOW DATABASES
# Out:
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">namespace</td></tr><tr><td>default</td></tr><tr><td>landing</td></tr><tr><td>sales_demo</td></tr></table>

# %%
# %%sparksql
# /* show tables in current (default) database */
# SHOW TABLES
# Out:
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">namespace</td><td style="font-weight: bold">tableName</td><td style="font-weight: bold">isTemporary</td></tr></table>

# %%
# %%sparksql
# /* show tables in a certain schema */
# SHOW TABLES IN landing
# Out:
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">namespace</td><td style="font-weight: bold">tableName</td><td style="font-weight: bold">isTemporary</td></tr><tr><td>landing</td><td>commercial_properties</td><td>False</td></tr></table>

# %%
# %%sparksql
# /* change current schema/database */
# USE sales_demo
# Out:
# <table><tr style="border-bottom: 1px solid"></tr></table>

# %%
# %%sparksql
# SHOW TABLES
# Out:
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">namespace</td><td style="font-weight: bold">tableName</td><td style="font-weight: bold">isTemporary</td></tr><tr><td>sales_demo</td><td>customers</td><td>False</td></tr><tr><td>sales_demo</td><td>products</td><td>False</td></tr><tr><td>sales_demo</td><td>sales_details</td><td>False</td></tr><tr><td>sales_demo</td><td>sales_orders</td><td>False</td></tr><tr><td>sales_demo</td><td>stores</td><td>False</td></tr></table>

# %%
# %%sparksql
# DESCRIBE TABLE customers
# Out:
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">col_name</td><td style="font-weight: bold">data_type</td><td style="font-weight: bold">comment</td></tr><tr><td>Address</td><td>string</td><td>null</td></tr><tr><td>City</td><td>string</td><td>null</td></tr><tr><td>CustomerID</td><td>bigint</td><td>null</td></tr><tr><td>Name</td><td>string</td><td>null</td></tr><tr><td>State</td><td>string</td><td>null</td></tr><tr><td>ZipCode</td><td>string</td><td>null</td></tr></table>

# %%
# %%sparksql
# DESCRIBE TABLE EXTENDED customers
# Out:
# only showing top 20 row(s)
# ...

# %%
# %%sparksql
# SELECT * FROM customers
# ORDER BY Name DESC
# LIMIT 100
# Out:
# only showing top 20 row(s)
# ...

# %%
spark.sparkContext.uiWebUrl
# Out:
# 'http://sparkplayground.mshome.net:4041'
