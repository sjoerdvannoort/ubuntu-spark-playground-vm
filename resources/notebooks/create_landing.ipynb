# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS landing")
# create external table
spark.catalog.getDatabase("landing")
spark.sql("DROP TABLE IF EXISTS landing.commercial_properties")
spark.catalog.createTable(
    tableName = "landing.commercial_properties",
    source = "csv",
    description = "property values",
    header="true", delimiter=",", path="/shared/sourcedata/commercial_property/commercial_property_snapshots_100_M39.csv", inferSchema="true")
# Out:
# DataFrame[date: date, property_id: string, street: string, street_number: int, city: string, zip_code: int, category: string, property_value: double, energy_label: string]

# %%
spark.table("landing.commercial_properties").where("energy_label='B'").show()
# Out:
# +----------+-----------+----------------+-------------+-------------+--------+---------+--------------+------------+
# |      date|property_id|          street|street_number|         city|zip_code| category|property_value|energy_label|
# +----------+-----------+----------------+-------------+-------------+--------+---------+--------------+------------+
# |2022-01-01|       P016|     Main Street|          176|  Rocky Mount|   28272| Workshop|     158234.91|           B|
# |2022-01-01|       P017|     High Street|          945|         Cary|   28280| Workshop|     177098.37|           B|
# |2022-01-01|       P021|Rocky Mount Road|          644|Winston-Salem|   28374| Workshop|     283300.13|           B|
# |2022-01-01|       P027|      River Road|          174| Fayetteville|   28382| Workshop|      95858.03|           B|
# |2022-01-01|       P029|      River Road|          601|   Wilmington|   27785| Workshop|     201464.95|           B|
# |2022-01-01|       P036| Blue Ridge Road|          790|  Rocky Mount|   27371|Warehouse|     264638.21|           B|
# |2022-01-01|       P040|   Spruce Street|          502|  Rocky Mount|   27315|   Office|     410709.97|           B|
# |2022-01-01|       P043|     Park Avenue|          999|      Concord|   27723|   Office|     250126.84|           B|
# |2022-01-01|       P052| Sycamore Street|            8|       Durham|   27669|   Office|     111049.06|           B|
# |2022-01-01|       P053| Magnolia Street|          794|  Chapel Hill|   28141|Warehouse|     266400.46|           B|
# |2022-01-01|       P077|      River Road|          116|   Wilmington|   28035|Warehouse|      61565.53|           B|
# |2022-01-01|       P082|   Winter Street|          653|       Durham|   27002|   Office|     184860.59|           B|
# |2022-01-01|       P083|   Walnut Street|          908|         Apex|   28946|   Office|     265880.94|           B|
# |2022-01-01|       P091|  Cape Fear Road|          859|    Charlotte|   28487|   Office|     254435.28|           B|
# |2022-01-01|       P098|  Hickory Street|          526|       Monroe|   28067|   Office|     145057.86|           B|
# |2022-01-01|       P099|    Birch Street|          500|    Charlotte|   28416|Warehouse|     128759.27|           B|
# |2022-01-02|       P016|     Main Street|          176|  Rocky Mount|   28272| Workshop|     158234.91|           B|
# |2022-01-02|       P017|     High Street|          945|         Cary|   28280| Workshop|     177098.37|           B|
# |2022-01-02|       P021|Rocky Mount Road|          644|Winston-Salem|   28374| Workshop|     283300.13|           B|
# |2022-01-02|       P027|      River Road|          174| Fayetteville|   28382| Workshop|      95858.03|           B|
# +----------+-----------+----------------+-------------+-------------+--------+---------+--------------+------------+
# only showing top 20 rows

# %%
# %%sparksql
# select * from landing.commercial_properties order by city
# Out:
# only showing top 20 row(s)
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">date</td><td style="font-weight: bold">property_id</td><td style="font-weight: bold">street</td><td style="font-weight: bold">street_number</td><td style="font-weight: bold">city</td><td style="font-weight: bold">zip_code</td><td style="font-weight: bold">category</td><td style="font-weight: bold">property_value</td><td style="font-weight: bold">energy_label</td></tr><tr><td>2025-03-31</td><td>P058</td><td>Rocky Mount Road</td><td>652</td><td>Apex</td><td>28001</td><td>Warehouse</td><td>707807.02</td><td>B</td></tr><tr><td>2023-08-20</td><td>P058</td><td>Rocky Mount Road</td><td>652</td><td>Apex</td><td>28001</td><td>Warehouse</td><td>349292.39</td><td>B</td></tr><tr><td>2022-01-05</td><td>P060</td><td>Autumn Lane</td><td>452</td><td>Apex</td><td>28672</td><td>Workshop</td><td>304650.14</td><td>E</td></tr><tr><td>2023-08-25</td><td>P058</td><td>Rocky Mount Road</td><td>652</td><td>Apex</td><td>28001</td><td>Warehouse</td><td>349292.39</td><td>B</td></tr><tr><td>2025-03-31</td><td>P060</td><td>Autumn Lane</td><td>452</td><td>Apex</td><td>28672</td><td>Workshop</td><td>672443.57</td><td>E</td></tr><tr><td>2023-08-20</td><td>P060</td><td>Autumn Lane</td><td>452</td><td>Apex</td><td>28672</td><td>Workshop</td><td>417659.09</td><td>F</td></tr><tr><td>2022-01-10</td><td>P060</td><td>Autumn Lane</td><td>452</td><td>Apex</td><td>28672</td><td>Workshop</td><td>304650.14</td><td>E</td></tr><tr><td>2023-08-17</td><td>P058</td><td>Rocky Mount Road</td><td>652</td><td>Apex</td><td>28001</td><td>Warehouse</td><td>330615.61</td><td>B</td></tr><tr><td>2025-03-31</td><td>P065</td><td>Sycamore Street</td><td>951</td><td>Apex</td><td>27656</td><td>Warehouse</td><td>956689.64</td><td>B</td></tr><tr><td>2023-08-20</td><td>P065</td><td>Sycamore Street</td><td>951</td><td>Apex</td><td>27656</td><td>Warehouse</td><td>633319.14</td><td>B</td></tr><tr><td>2022-01-05</td><td>P065</td><td>Sycamore Street</td><td>951</td><td>Apex</td><td>27656</td><td>Warehouse</td><td>425529.14</td><td>E</td></tr><tr><td>2023-08-17</td><td>P065</td><td>Sycamore Street</td><td>951</td><td>Apex</td><td>27656</td><td>Warehouse</td><td>633319.14</td><td>B</td></tr><tr><td>2025-03-31</td><td>P083</td><td>Walnut Street</td><td>908</td><td>Apex</td><td>28946</td><td>Office</td><td>602677.75</td><td>B</td></tr><tr><td>2023-08-20</td><td>P083</td><td>Walnut Street</td><td>908</td><td>Apex</td><td>28946</td><td>Office</td><td>384595.54</td><td>B</td></tr><tr><td>2022-01-01</td><td>P060</td><td>Autumn Lane</td><td>452</td><td>Apex</td><td>28672</td><td>Workshop</td><td>304650.14</td><td>E</td></tr><tr><td>2023-08-18</td><td>P058</td><td>Rocky Mount Road</td><td>652</td><td>Apex</td><td>28001</td><td>Warehouse</td><td>349292.39</td><td>B</td></tr><tr><td>2022-01-05</td><td>P083</td><td>Walnut Street</td><td>908</td><td>Apex</td><td>28946</td><td>Office</td><td>265880.94</td><td>B</td></tr><tr><td>2023-08-21</td><td>P058</td><td>Rocky Mount Road</td><td>652</td><td>Apex</td><td>28001</td><td>Warehouse</td><td>349292.39</td><td>B</td></tr><tr><td>2022-01-01</td><td>P083</td><td>Walnut Street</td><td>908</td><td>Apex</td><td>28946</td><td>Office</td><td>265880.94</td><td>B</td></tr><tr><td>2023-08-18</td><td>P083</td><td>Walnut Street</td><td>908</td><td>Apex</td><td>28946</td><td>Office</td><td>384595.54</td><td>B</td></tr></table>

# %%
get_ipython().profile_dir.startup_dir
# Out:
# '/root/.ipython/profile_default/startup'

# %%
spark.table("landing.commercial_properties").columns[:4]
# Out:
# ['date', 'property_id', 'street', 'street_number']

# %%
df = spark.table("landing.commercial_properties")
df.select(df.columns[:4]).show()
# Out:
# +----------+-----------+-----------------+-------------+
# |      date|property_id|           street|street_number|
# +----------+-----------+-----------------+-------------+
# |2022-01-01|       P001|Greensboro Street|          430|
# |2022-01-01|       P002|      Pine Street|          634|
# |2022-01-01|       P003|   Tar Heel Drive|          846|
# |2022-01-01|       P004|       Ash Street|          931|
# |2022-01-01|       P005|    Spring Street|          759|
# |2022-01-01|       P006|       Oak Street|          933|
# |2022-01-01|       P007|       Ridge Road|           90|
# |2022-01-01|       P008|   Tar Heel Drive|          389|
# |2022-01-01|       P009|     Broad Street|           98|
# |2022-01-01|       P010|  Hillcrest Drive|          144|
# |2022-01-01|       P011|    Spring Street|          419|
# |2022-01-01|       P012|  Carolina Avenue|          847|
# |2022-01-01|       P013|       Ridge Road|          183|
# |2022-01-01|       P014|  Hillcrest Drive|          370|
# |2022-01-01|       P015|Greensboro Street|          483|
# |2022-01-01|       P016|      Main Street|          176|
# |2022-01-01|       P017|      High Street|          945|
# |2022-01-01|       P018|       Ash Street|           98|
# |2022-01-01|       P019|      Pine Street|          234|
# |2022-01-01|       P020|    Durham Street|          795|
# +----------+-----------+-----------------+-------------+
# only showing top 20 rows

# %%
df.columns
# Out:
# ['date',
#  'property_id',
#  'street',
#  'street_number',
#  'city',
#  'zip_code',
#  'category',
#  'property_value',
#  'energy_label']

# %%
df.schema
# Out:
# StructType([StructField('date', DateType(), True), StructField('property_id', StringType(), True), StructField('street', StringType(), True), StructField('street_number', IntegerType(), True), StructField('city', StringType(), True), StructField('zip_code', IntegerType(), True), StructField('category', StringType(), True), StructField('property_value', DoubleType(), True), StructField('energy_label', StringType(), True)])

# %%
current_city = "Raleigh"

df.where(f"City='{current_city}'").show()
# Out:
# +----------+-----------+-----------------+-------------+-------+--------+--------+--------------+------------+
# |      date|property_id|           street|street_number|   city|zip_code|category|property_value|energy_label|
# +----------+-----------+-----------------+-------------+-------+--------+--------+--------------+------------+
# |2022-01-01|       P001|Greensboro Street|          430|Raleigh|   28457|Workshop|     230818.13|           A|
# |2022-01-01|       P019|      Pine Street|          234|Raleigh|   28880|Workshop|     258647.08|           D|
# |2022-01-01|       P068|    Winter Street|          626|Raleigh|   28557|  Office|      52365.54|           D|
# |2022-01-02|       P001|Greensboro Street|          430|Raleigh|   28457|Workshop|     230818.13|           A|
# |2022-01-02|       P019|      Pine Street|          234|Raleigh|   28880|Workshop|     258647.08|           D|
# |2022-01-02|       P068|    Winter Street|          626|Raleigh|   28557|  Office|      52365.54|           D|
# |2022-01-03|       P001|Greensboro Street|          430|Raleigh|   28457|Workshop|     230818.13|           A|
# |2022-01-03|       P019|      Pine Street|          234|Raleigh|   28880|Workshop|     258647.08|           D|
# |2022-01-03|       P068|    Winter Street|          626|Raleigh|   28557|  Office|      52365.54|           D|
# |2022-01-04|       P001|Greensboro Street|          430|Raleigh|   28457|Workshop|     230818.13|           A|
# |2022-01-04|       P019|      Pine Street|          234|Raleigh|   28880|Workshop|     258647.08|           D|
# |2022-01-04|       P068|    Winter Street|          626|Raleigh|   28557|  Office|      52365.54|           D|
# |2022-01-05|       P001|Greensboro Street|          430|Raleigh|   28457|Workshop|     230818.13|           A|
# |2022-01-05|       P019|      Pine Street|          234|Raleigh|   28880|Workshop|     258647.08|           D|
# |2022-01-05|       P068|    Winter Street|          626|Raleigh|   28557|  Office|      52365.54|           D|
# |2022-01-06|       P001|Greensboro Street|          430|Raleigh|   28457|Workshop|     230818.13|           A|
# |2022-01-06|       P019|      Pine Street|          234|Raleigh|   28880|Workshop|     258647.08|           D|
# |2022-01-06|       P068|    Winter Street|          626|Raleigh|   28557|  Office|      52365.54|           D|
# |2022-01-07|       P001|Greensboro Street|          430|Raleigh|   28457|Workshop|     230818.13|           A|
# |2022-01-07|       P019|      Pine Street|          234|Raleigh|   28880|Workshop|     258647.08|           D|
# +----------+-----------+-----------------+-------------+-------+--------+--------+--------------+------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import *

current_city = "Raleigh"

df.where(col("City") == lit(current_city)).show()
# Out:
# +----------+-----------+-----------------+-------------+-------+--------+--------+--------------+------------+
# |      date|property_id|           street|street_number|   city|zip_code|category|property_value|energy_label|
# +----------+-----------+-----------------+-------------+-------+--------+--------+--------------+------------+
# |2022-01-01|       P001|Greensboro Street|          430|Raleigh|   28457|Workshop|     230818.13|           A|
# |2022-01-01|       P019|      Pine Street|          234|Raleigh|   28880|Workshop|     258647.08|           D|
# |2022-01-01|       P068|    Winter Street|          626|Raleigh|   28557|  Office|      52365.54|           D|
# |2022-01-02|       P001|Greensboro Street|          430|Raleigh|   28457|Workshop|     230818.13|           A|
# |2022-01-02|       P019|      Pine Street|          234|Raleigh|   28880|Workshop|     258647.08|           D|
# |2022-01-02|       P068|    Winter Street|          626|Raleigh|   28557|  Office|      52365.54|           D|
# |2022-01-03|       P001|Greensboro Street|          430|Raleigh|   28457|Workshop|     230818.13|           A|
# |2022-01-03|       P019|      Pine Street|          234|Raleigh|   28880|Workshop|     258647.08|           D|
# |2022-01-03|       P068|    Winter Street|          626|Raleigh|   28557|  Office|      52365.54|           D|
# |2022-01-04|       P001|Greensboro Street|          430|Raleigh|   28457|Workshop|     230818.13|           A|
# |2022-01-04|       P019|      Pine Street|          234|Raleigh|   28880|Workshop|     258647.08|           D|
# |2022-01-04|       P068|    Winter Street|          626|Raleigh|   28557|  Office|      52365.54|           D|
# |2022-01-05|       P001|Greensboro Street|          430|Raleigh|   28457|Workshop|     230818.13|           A|
# |2022-01-05|       P019|      Pine Street|          234|Raleigh|   28880|Workshop|     258647.08|           D|
# |2022-01-05|       P068|    Winter Street|          626|Raleigh|   28557|  Office|      52365.54|           D|
# |2022-01-06|       P001|Greensboro Street|          430|Raleigh|   28457|Workshop|     230818.13|           A|
# |2022-01-06|       P019|      Pine Street|          234|Raleigh|   28880|Workshop|     258647.08|           D|
# |2022-01-06|       P068|    Winter Street|          626|Raleigh|   28557|  Office|      52365.54|           D|
# |2022-01-07|       P001|Greensboro Street|          430|Raleigh|   28457|Workshop|     230818.13|           A|
# |2022-01-07|       P019|      Pine Street|          234|Raleigh|   28880|Workshop|     258647.08|           D|
# +----------+-----------+-----------------+-------------+-------+--------+--------+--------------+------------+
# only showing top 20 rows
